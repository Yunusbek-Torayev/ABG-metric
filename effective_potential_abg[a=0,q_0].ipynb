# %%
import numpy as np
import sympy as sp 
import matplotlib.pyplot as plt
from matplotlib import style

r,θ,ϕ,M,q,L,Q = sp.symbols('r,θ,ϕ,M,q,L,Q')

# %%
A = ((3*M/(2*Q))*sp.sqrt(1+Q**2/r**2)-Q/r)*(1+Q**2/r**2)**(-3) - (3*M/(2*Q))
A
# Out:
# -3*M/(2*Q) + (3*M*sqrt(Q**2/r**2 + 1)/(2*Q) - Q/r)/(Q**2/r**2 + 1)**3

# %%
Eff = q*A + sp.sqrt((1-2*M*r**2/((r**2+Q**2)**2)+r**2*Q**2/((r**2+Q**2)**2))*(1+L**2/r**2))
Eff
# Out:
# q*(-3*M/(2*Q) + (3*M*sqrt(Q**2/r**2 + 1)/(2*Q) - Q/r)/(Q**2/r**2 + 1)**3) + sqrt((L**2/r**2 + 1)*(-2*M*r**2/(Q**2 + r**2)**2 + Q**2*r**2/(Q**2 + r**2)**2 + 1))

# %%
E1 = (((( (1-2*M*r**2/((r**2+Q**2)**2)+r**2*Q**2/((r**2+Q**2)**2))*(1+L**2/r**2) ).subs(M,1)).subs(Q,0)).subs(L,5)).subs(q,0.3)
E2 = (((( (1-2*M*r**2/((r**2+Q**2)**2)+r**2*Q**2/((r**2+Q**2)**2))*(1+L**2/r**2) ).subs(M,1)).subs(Q,0.2)).subs(L,5)).subs(q,0.3)
E3 = (((( (1-2*M*r**2/((r**2+Q**2)**2)+r**2*Q**2/((r**2+Q**2)**2))*(1+L**2/r**2) ).subs(M,1)).subs(Q,0.4)).subs(L,5)).subs(q,0.3)
E4 = (((( (1-2*M*r**2/((r**2+Q**2)**2)+r**2*Q**2/((r**2+Q**2)**2))*(1+L**2/r**2) ).subs(M,1)).subs(Q,0.6)).subs(L,5)).subs(q,0.3)


print(E1)
print(E2)
print(E3)
print(E4)
# Out:
# (1 - 2/r**2)*(1 + 25/r**2)
# (1 + 25/r**2)*(-1.96*r**2/(r**2 + 0.04)**2 + 1)
# (1 + 25/r**2)*(-1.84*r**2/(r**2 + 0.16)**2 + 1)
# (1 + 25/r**2)*(-1.64*r**2/(r**2 + 0.36)**2 + 1)

# %%
r = np.linspace(0,4,1000)

E1 = (1 - 2/r**2)*(1 + 25/r**2)
E2 = (1 + 25/r**2)*(-1.96*r**2/(r**2 + 0.04)**2 + 1)
E3 = (1 + 25/r**2)*(-1.84*r**2/(r**2 + 0.16)**2 + 1)
E4 = (1 + 25/r**2)*(-1.64*r**2/(r**2 + 0.36)**2 + 1)

#plt.figure(dpi=200)

ax = plt.axes()
#ax.set(facecolor = "azure")

#plt.title("Effective potential of test particle, q=0.3")

plt.xlabel("r/M")
plt.ylabel("$E_{eff}$")
plt.grid(True)

plt.xlim(0,4)
plt.ylim(-12,7)
plt.axhline(color = 'k')
style.use('seaborn')

#plt.xticks(np.arange(0.5, 4, step=1))
#plt.yticks(np.arange(-3, 7, step=1))


plt.plot(r,E1, '--', label="Q=0  ", color='black', lw='1.2')
plt.plot(r,E2, '--', label="Q=0.2", color='green', lw='1.2')
plt.plot(r,E3, '--', label="Q=0.4", color='blue', lw='1.2' )
plt.plot(r,E4, '--', label="Q=0.6", color='red', lw='1.2' )

plt.legend(loc="upper right")

plt.show()
# Out:
# /tmp/ipykernel_10830/2895334830.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   E1 = (1 - 2/r**2)*(1 + 25/r**2)
# /tmp/ipykernel_10830/2895334830.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   E2 = (1 + 25/r**2)*(-1.96*r**2/(r**2 + 0.04)**2 + 1)
# /tmp/ipykernel_10830/2895334830.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   E3 = (1 + 25/r**2)*(-1.84*r**2/(r**2 + 0.16)**2 + 1)
# /tmp/ipykernel_10830/2895334830.py:6: RuntimeWarning: divide by zero encountered in true_divide
#   E4 = (1 + 25/r**2)*(-1.64*r**2/(r**2 + 0.36)**2 + 1)
