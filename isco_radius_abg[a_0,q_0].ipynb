# %%
import numpy as np
import sympy as sp
sp.init_printing()
import matplotlib.pyplot as plt

# %%
q,a,r,θ,ϕ,M,Q,L = sp.symbols('q,a,r,θ,ϕ,M,Q,L')

# %%
Σ = r**2 + a**2*sp.cos(θ)
Σ
# Out:
#  2           2
# a ⋅cos(θ) + r

# %%
f = (1-(2*M*r*sp.sqrt(Σ))/((Σ+Q**2)**(3/2))+(Σ*Q**2)/((Σ+Q**2)**2))
f
# Out:
#            ________________                      -1.5     2 ⎛ 2           2⎞
#           ╱  2           2  ⎛ 2    2           2⎞        Q ⋅⎝a ⋅cos(θ) + r ⎠
# - 2⋅M⋅r⋅╲╱  a ⋅cos(θ) + r  ⋅⎝Q  + a ⋅cos(θ) + r ⎠     + ──────────────────────
#                                                                              2
#                                                         ⎛ 2    2           2⎞
#                                                         ⎝Q  + a ⋅cos(θ) + r ⎠
#
#
#
#  + 1

# %%
A = ((3*M/(2*Q))*sp.sqrt(1+Q**2/r**2)-Q/r)*(1+Q**2/r**2)**(-3) - (3*M/(2*Q))
A
# Out:
#                   ________
#                  ╱  2
#                 ╱  Q
#         3⋅M⋅   ╱   ── + 1
#               ╱     2
#             ╲╱     r         Q
#         ────────────────── - ─
#   3⋅M          2⋅Q           r
# - ─── + ──────────────────────
#   2⋅Q                 3
#               ⎛ 2    ⎞
#               ⎜Q     ⎟
#               ⎜── + 1⎟
#               ⎜ 2    ⎟
#               ⎝r     ⎠

# %%
Eff = q*A + f*(1+L**2/r**2)
Eff
# Out:
#   ⎛                  ________    ⎞
#   ⎜                 ╱  2         ⎟
#   ⎜                ╱  Q          ⎟
#   ⎜        3⋅M⋅   ╱   ── + 1     ⎟
#   ⎜              ╱     2         ⎟
#   ⎜            ╲╱     r         Q⎟
#   ⎜        ────────────────── - ─⎟   ⎛ 2    ⎞ ⎛           ________________
#   ⎜  3⋅M          2⋅Q           r⎟   ⎜L     ⎟ ⎜          ╱  2           2  ⎛ 2
# q⋅⎜- ─── + ──────────────────────⎟ + ⎜── + 1⎟⋅⎜- 2⋅M⋅r⋅╲╱  a ⋅cos(θ) + r  ⋅⎝Q
#   ⎜  2⋅Q                 3       ⎟   ⎜ 2    ⎟ ⎜
#   ⎜              ⎛ 2    ⎞        ⎟   ⎝r     ⎠ ⎜
#   ⎜              ⎜Q     ⎟        ⎟            ⎝
#   ⎜              ⎜── + 1⎟        ⎟
#   ⎜              ⎜ 2    ⎟        ⎟
#   ⎝              ⎝r     ⎠        ⎠
#
#
#
#
#
#
#
#                   -1.5     2 ⎛ 2           2⎞      ⎞
#     2           2⎞        Q ⋅⎝a ⋅cos(θ) + r ⎠      ⎟
#  + a ⋅cos(θ) + r ⎠     + ────────────────────── + 1⎟
#                                               2    ⎟
# ...

# %%
Eff1 = ((((((Eff.subs(L,5)).subs(M,1)).subs(θ,sp.pi/3))).subs(Q,0.3)).subs(q,0.2)).subs(a,0)
Eff2 = ((((((Eff.subs(L,5)).subs(M,1)).subs(θ,sp.pi/3))).subs(Q,0.3)).subs(q,0.2)).subs(a,0.2)
Eff3 = ((((((Eff.subs(L,5)).subs(M,1)).subs(θ,sp.pi/3))).subs(Q,0.3)).subs(q,0.2)).subs(a,0.5)
Eff4 = ((((((Eff.subs(L,5)).subs(M,1)).subs(θ,sp.pi/3))).subs(Q,0.3)).subs(q,0.2)).subs(a,0.97)

# %%
ddEff1 = sp.diff(Eff1,r,2)
ddEff2 = sp.diff(Eff2,r,2)
ddEff3 = sp.diff(Eff3,r,2)
ddEff4 = sp.diff(Eff4,r,2)

print(ddEff1)
print("===================")
print(ddEff2)
print("===================")
print(ddEff3)
print("===================")
print(ddEff4)
# Out:
# (1 + 25/r**2)*(2.16*r**4/(r**2 + 0.09)**4 - 30.0*r**3*sqrt(r**2)/(r**2 + 0.09)**3.5 - 1.8*r**2/(r**2 + 0.09)**3 + 30.0*r*sqrt(r**2)/(r**2 + 0.09)**2.5 + 0.18/(r**2 + 0.09)**2 - 4*sqrt(r**2)/(r*(r**2 + 0.09)**1.5)) + 100*(0.36*r**3/(r**2 + 0.09)**3 - 6.0*r**2*sqrt(r**2)/(r**2 + 0.09)**2.5 - 0.18*r/(r**2 + 0.09)**2 + 4*sqrt(r**2)/(r**2 + 0.09)**1.5)/r**3 - (0.12 - 0.27/(r*sqrt(1 + 0.09/r**2)) + 0.0081/(r**3*(1 + 0.09/r**2)**(3/2)))/(r**3*(1 + 0.09/r**2)**3) + 150*(0.09*r**2/(r**2 + 0.09)**2 - 2*r*sqrt(r**2)/(r**2 + 0.09)**1.5 + 1)/r**4 - (1.62*sqrt(1 + 0.09/r**2) - 0.0972/r)/(r**4*(1 + 0.09/r**2)**4) + (0.0648 - 0.0972/(r*sqrt(1 + 0.09/r**2)))/(r**5*(1 + 0.09/r**2)**4) + (0.3888*sqrt(1 + 0.09/r**2) - 0.023328/r)/(r**6*(1 + 0.09/r**2)**5)
# ...

# %%
r = np.linspace(0.2,10,1000)

ddEff1 = (1 + 25/r**2)*(2.16*r**4/(r**2 + 0.09)**4 - 30.0*r**3*np.sqrt(r**2)/(r**2 + 0.09)**3.5 - 1.8*r**2/(r**2 + 0.09)**3 + 30.0*r*np.sqrt(r**2)/(r**2 + 0.09)**2.5 + 0.18/(r**2 + 0.09)**2 - 4*np.sqrt(r**2)/(r*(r**2 + 0.09)**1.5)) + 100*(0.36*r**3/(r**2 + 0.09)**3 - 6.0*r**2*np.sqrt(r**2)/(r**2 + 0.09)**2.5 - 0.18*r/(r**2 + 0.09)**2 + 4*np.sqrt(r**2)/(r**2 + 0.09)**1.5)/r**3 - (0.12 - 0.27/(r*np.sqrt(1 + 0.09/r**2)) + 0.0081/(r**3*(1 + 0.09/r**2)**(3/2)))/(r**3*(1 + 0.09/r**2)**3) + 150*(0.09*r**2/(r**2 + 0.09)**2 - 2*r*np.sqrt(r**2)/(r**2 + 0.09)**1.5 + 1)/r**4 - (1.62*np.sqrt(1 + 0.09/r**2) - 0.0972/r)/(r**4*(1 + 0.09/r**2)**4) + (0.0648 - 0.0972/(r*np.sqrt(1 + 0.09/r**2)))/(r**5*(1 + 0.09/r**2)**4) + (0.3888*np.sqrt(1 + 0.09/r**2) - 0.023328/r)/(r**6*(1 + 0.09/r**2)**5)

ddEff2 = (1 + 25/r**2)*(-30.0*r**3*np.sqrt(r**2 + 0.02)/(r**2 + 0.11)**3.5 + 12.0*r**3/(np.sqrt(r**2 + 0.02)*(r**2 + 0.11)**2.5) + 2*r**3/((r**2 + 0.02)**(3/2)*(r**2 + 0.11)**1.5) + 2.16*r**2*(r**2 + 0.02)/(r**2 + 0.11)**4 - 1.44*r**2/(r**2 + 0.11)**3 + 18.0*r*np.sqrt(r**2 + 0.02)/(r**2 + 0.11)**2.5 - 6*r/(np.sqrt(r**2 + 0.02)*(r**2 + 0.11)**1.5) - (0.36*r**2 + 0.0072)/(r**2 + 0.11)**3 + 0.18/(r**2 + 0.11)**2) + 100*(-6.0*r**2*np.sqrt(r**2 + 0.02)/(r**2 + 0.11)**2.5 + 2*r**2/(np.sqrt(r**2 + 0.02)*(r**2 + 0.11)**1.5) + 0.36*r*(r**2 + 0.02)/(r**2 + 0.11)**3 - 0.18*r/(r**2 + 0.11)**2 + 2*np.sqrt(r**2 + 0.02)/(r**2 + 0.11)**1.5)/r**3 - (0.12 - 0.27/(r*np.sqrt(1 + 0.09/r**2)) + 0.0081/(r**3*(1 + 0.09/r**2)**(3/2)))/(r**3*(1 + 0.09/r**2)**3) + 150*(-2*r*np.sqrt(r**2 + 0.02)/(r**2 + 0.11)**1.5 + (0.09*r**2 + 0.0018)/(r**2 + 0.11)**2 + 1)/r**4 - (1.62*np.sqrt(1 + 0.09/r**2) - 0.0972/r)/(r**4*(1 + 0.09/r**2)**4) + (0.0648 - 0.0972/(r*np.sqrt(1 + 0.09/r**2)))/(r**5*(1 + 0.09/r**2)**4) + (0.3888*np.sqrt(1 + 0.09/r**2) - 0.023328/r)/(r**6*(1 + 0.09/r**2)**5)

ddEff3 = (1 + 25/r**2)*(-30.0*r**3*np.sqrt(r**2 + 0.125)/(r**2 + 0.215)**3.5 + 12.0*r**3/(np.sqrt(r**2 + 0.125)*(r**2 + 0.215)**2.5) + 2*r**3/((r**2 + 0.125)**(3/2)*(r**2 + 0.215)**1.5) + 2.16*r**2*(r**2 + 0.125)/(r**2 + 0.215)**4 - 1.44*r**2/(r**2 + 0.215)**3 + 18.0*r*np.sqrt(r**2 + 0.125)/(r**2 + 0.215)**2.5 - 6*r/(np.sqrt(r**2 + 0.125)*(r**2 + 0.215)**1.5) - (0.36*r**2 + 0.045)/(r**2 + 0.215)**3 + 0.18/(r**2 + 0.215)**2) + 100*(-6.0*r**2*np.sqrt(r**2 + 0.125)/(r**2 + 0.215)**2.5 + 2*r**2/(np.sqrt(r**2 + 0.125)*(r**2 + 0.215)**1.5) + 0.36*r*(r**2 + 0.125)/(r**2 + 0.215)**3 - 0.18*r/(r**2 + 0.215)**2 + 2*np.sqrt(r**2 + 0.125)/(r**2 + 0.215)**1.5)/r**3 - (0.12 - 0.27/(r*np.sqrt(1 + 0.09/r**2)) + 0.0081/(r**3*(1 + 0.09/r**2)**(3/2)))/(r**3*(1 + 0.09/r**2)**3) + 150*(-2*r*np.sqrt(r**2 + 0.125)/(r**2 + 0.215)**1.5 + (0.09*r**2 + 0.01125)/(r**2 + 0.215)**2 + 1)/r**4 - (1.62*np.sqrt(1 + 0.09/r**2) - 0.0972/r)/(r**4*(1 + 0.09/r**2)**4) + (0.0648 - 0.0972/(r*np.sqrt(1 + 0.09/r**2)))/(r**5*(1 + 0.09/r**2)**4) + (0.3888*np.sqrt(1 + 0.09/r**2) - 0.023328/r)/(r**6*(1 + 0.09/r**2)**5)

ddEff4 = (1 + 25/r**2)*(-30.0*r**3*np.sqrt(r**2 + 0.47045)/(r**2 + 0.56045)**3.5 + 12.0*r**3/(np.sqrt(r**2 + 0.47045)*(r**2 + 0.56045)**2.5) + 2*r**3/((r**2 + 0.47045)**(3/2)*(r**2 + 0.56045)**1.5) + 2.16*r**2*(r**2 + 0.47045)/(r**2 + 0.56045)**4 - 1.44*r**2/(r**2 + 0.56045)**3 + 18.0*r*np.sqrt(r**2 + 0.47045)/(r**2 + 0.56045)**2.5 - 6*r/(np.sqrt(r**2 + 0.47045)*(r**2 + 0.56045)**1.5) - (0.36*r**2 + 0.169362)/(r**2 + 0.56045)**3 + 0.18/(r**2 + 0.56045)**2) + 100*(-6.0*r**2*np.sqrt(r**2 + 0.47045)/(r**2 + 0.56045)**2.5 + 2*r**2/(np.sqrt(r**2 + 0.47045)*(r**2 + 0.56045)**1.5) + 0.36*r*(r**2 + 0.47045)/(r**2 + 0.56045)**3 - 0.18*r/(r**2 + 0.56045)**2 + 2*np.sqrt(r**2 + 0.47045)/(r**2 + 0.56045)**1.5)/r**3 - (0.12 - 0.27/(r*np.sqrt(1 + 0.09/r**2)) + 0.0081/(r**3*(1 + 0.09/r**2)**(3/2)))/(r**3*(1 + 0.09/r**2)**3) + 150*(-2*r*np.sqrt(r**2 + 0.47045)/(r**2 + 0.56045)**1.5 + (0.09*r**2 + 0.0423405)/(r**2 + 0.56045)**2 + 1)/r**4 - (1.62*np.sqrt(1 + 0.09/r**2) - 0.0972/r)/(r**4*(1 + 0.09/r**2)**4) + (0.0648 - 0.0972/(r*np.sqrt(1 + 0.09/r**2)))/(r**5*(1 + 0.09/r**2)**4) + (0.3888*np.sqrt(1 + 0.09/r**2) - 0.023328/r)/(r**6*(1 + 0.09/r**2)**5)

#plt.figure(figsize=(8,5), dpi=200)

ax = plt.axes()

plt.xlabel("r/M")
plt.ylabel("$d^2 E_{eff}/dr^2$")
plt.grid(True)

plt.xlim(3,10)
plt.ylim(-0.05,0.05)

plt.xticks(np.arange(3, 10, step=1))

plt.plot(r,ddEff1, '--', label="a=0", color='black', lw='1.2' )
plt.plot(r,ddEff2, '--', label="a=0.2", color='red', lw='1.2')
plt.plot(r,ddEff3, '--', label="a=0.5", color='green', lw='1.2')
plt.plot(r,ddEff4, '--', label="a=0.97", color='blue', lw='1.2' )
plt.axhline(color = 'k')

plt.legend(loc="upper right")

plt.show()

# %%
# ddEff1 dagi ISCO radius

from scipy.optimize import brentq
import matplotlib.pyplot as plt

def f(r):
    return (1 + 25/r**2)*(2.16*r**4/(r**2 + 0.09)**4 - 30.0*r**3*np.sqrt(r**2)/(r**2 + 0.09)**3.5 - 1.8*r**2/(r**2 + 0.09)**3 + 30.0*r*np.sqrt(r**2)/(r**2 + 0.09)**2.5 + 0.18/(r**2 + 0.09)**2 - 4*np.sqrt(r**2)/(r*(r**2 + 0.09)**1.5)) + 100*(0.36*r**3/(r**2 + 0.09)**3 - 6.0*r**2*np.sqrt(r**2)/(r**2 + 0.09)**2.5 - 0.18*r/(r**2 + 0.09)**2 + 4*np.sqrt(r**2)/(r**2 + 0.09)**1.5)/r**3 - (0.12 - 0.27/(r*np.sqrt(1 + 0.09/r**2)) + 0.0081/(r**3*(1 + 0.09/r**2)**(3/2)))/(r**3*(1 + 0.09/r**2)**3) + 150*(0.09*r**2/(r**2 + 0.09)**2 - 2*r*np.sqrt(r**2)/(r**2 + 0.09)**1.5 + 1)/r**4 - (1.62*np.sqrt(1 + 0.09/r**2) - 0.0972/r)/(r**4*(1 + 0.09/r**2)**4) + (0.0648 - 0.0972/(r*np.sqrt(1 + 0.09/r**2)))/(r**5*(1 + 0.09/r**2)**4) + (0.3888*np.sqrt(1 + 0.09/r**2) - 0.023328/r)/(r**6*(1 + 0.09/r**2)**5)

r = np.linspace(3, 10, 100)
plt.ylim(-0.05,0.05)
plt.plot(r, f(r))
plt.axhline(color = 'k')
root, info = brentq(f, 4, 5, full_output=True)
plt.axvline(x=root, color = 'r', **{'linestyle': 'dashed'})
print(root)
# Out:
# 4.395103765273303

# %%
# ddEff2 dagi ISCO radius
from scipy.optimize import brentq
import matplotlib.pyplot as plt

def f(r):
    return (1 + 25/r**2)*(-30.0*r**3*np.sqrt(r**2 + 0.02)/(r**2 + 0.11)**3.5 + 12.0*r**3/(np.sqrt(r**2 + 0.02)*(r**2 + 0.11)**2.5) + 2*r**3/((r**2 + 0.02)**(3/2)*(r**2 + 0.11)**1.5) + 2.16*r**2*(r**2 + 0.02)/(r**2 + 0.11)**4 - 1.44*r**2/(r**2 + 0.11)**3 + 18.0*r*np.sqrt(r**2 + 0.02)/(r**2 + 0.11)**2.5 - 6*r/(np.sqrt(r**2 + 0.02)*(r**2 + 0.11)**1.5) - (0.36*r**2 + 0.0072)/(r**2 + 0.11)**3 + 0.18/(r**2 + 0.11)**2) + 100*(-6.0*r**2*np.sqrt(r**2 + 0.02)/(r**2 + 0.11)**2.5 + 2*r**2/(np.sqrt(r**2 + 0.02)*(r**2 + 0.11)**1.5) + 0.36*r*(r**2 + 0.02)/(r**2 + 0.11)**3 - 0.18*r/(r**2 + 0.11)**2 + 2*np.sqrt(r**2 + 0.02)/(r**2 + 0.11)**1.5)/r**3 - (0.12 - 0.27/(r*np.sqrt(1 + 0.09/r**2)) + 0.0081/(r**3*(1 + 0.09/r**2)**(3/2)))/(r**3*(1 + 0.09/r**2)**3) + 150*(-2*r*np.sqrt(r**2 + 0.02)/(r**2 + 0.11)**1.5 + (0.09*r**2 + 0.0018)/(r**2 + 0.11)**2 + 1)/r**4 - (1.62*np.sqrt(1 + 0.09/r**2) - 0.0972/r)/(r**4*(1 + 0.09/r**2)**4) + (0.0648 - 0.0972/(r*np.sqrt(1 + 0.09/r**2)))/(r**5*(1 + 0.09/r**2)**4) + (0.3888*np.sqrt(1 + 0.09/r**2) - 0.023328/r)/(r**6*(1 + 0.09/r**2)**5)

r = np.linspace(3, 10, 100)
plt.ylim(-0.05,0.05)
plt.plot(r, f(r))
plt.axhline(color = 'k')
root, info = brentq(f, 4, 5, full_output=True)
plt.axvline(x=root, color = 'r', **{'linestyle': 'dashed'})
print(root)
# Out:
# 4.37668656056066

# %%
# ddEff3 dagi ISCO radius
from scipy.optimize import brentq
import matplotlib.pyplot as plt

def f(r):
    return (1 + 25/r**2)*(-30.0*r**3*np.sqrt(r**2 + 0.125)/(r**2 + 0.215)**3.5 + 12.0*r**3/(np.sqrt(r**2 + 0.125)*(r**2 + 0.215)**2.5) + 2*r**3/((r**2 + 0.125)**(3/2)*(r**2 + 0.215)**1.5) + 2.16*r**2*(r**2 + 0.125)/(r**2 + 0.215)**4 - 1.44*r**2/(r**2 + 0.215)**3 + 18.0*r*np.sqrt(r**2 + 0.125)/(r**2 + 0.215)**2.5 - 6*r/(np.sqrt(r**2 + 0.125)*(r**2 + 0.215)**1.5) - (0.36*r**2 + 0.045)/(r**2 + 0.215)**3 + 0.18/(r**2 + 0.215)**2) + 100*(-6.0*r**2*np.sqrt(r**2 + 0.125)/(r**2 + 0.215)**2.5 + 2*r**2/(np.sqrt(r**2 + 0.125)*(r**2 + 0.215)**1.5) + 0.36*r*(r**2 + 0.125)/(r**2 + 0.215)**3 - 0.18*r/(r**2 + 0.215)**2 + 2*np.sqrt(r**2 + 0.125)/(r**2 + 0.215)**1.5)/r**3 - (0.12 - 0.27/(r*np.sqrt(1 + 0.09/r**2)) + 0.0081/(r**3*(1 + 0.09/r**2)**(3/2)))/(r**3*(1 + 0.09/r**2)**3) + 150*(-2*r*np.sqrt(r**2 + 0.125)/(r**2 + 0.215)**1.5 + (0.09*r**2 + 0.01125)/(r**2 + 0.215)**2 + 1)/r**4 - (1.62*np.sqrt(1 + 0.09/r**2) - 0.0972/r)/(r**4*(1 + 0.09/r**2)**4) + (0.0648 - 0.0972/(r*np.sqrt(1 + 0.09/r**2)))/(r**5*(1 + 0.09/r**2)**4) + (0.3888*np.sqrt(1 + 0.09/r**2) - 0.023328/r)/(r**6*(1 + 0.09/r**2)**5)

r = np.linspace(3, 10, 100)
plt.ylim(-0.05,0.05)
plt.plot(r, f(r))
plt.axhline(color = 'k')
root, info = brentq(f, 4, 5, full_output=True)
plt.axvline(x=root, color = 'r', **{'linestyle': 'dashed'})
print(root)
# Out:
# 4.277637239432364

# %%
# ddEff4 dagi ISCO radius
from scipy.optimize import brentq
import matplotlib.pyplot as plt

def f(r):
    return (1 + 25/r**2)*(-30.0*r**3*np.sqrt(r**2 + 0.47045)/(r**2 + 0.56045)**3.5 + 12.0*r**3/(np.sqrt(r**2 + 0.47045)*(r**2 + 0.56045)**2.5) + 2*r**3/((r**2 + 0.47045)**(3/2)*(r**2 + 0.56045)**1.5) + 2.16*r**2*(r**2 + 0.47045)/(r**2 + 0.56045)**4 - 1.44*r**2/(r**2 + 0.56045)**3 + 18.0*r*np.sqrt(r**2 + 0.47045)/(r**2 + 0.56045)**2.5 - 6*r/(np.sqrt(r**2 + 0.47045)*(r**2 + 0.56045)**1.5) - (0.36*r**2 + 0.169362)/(r**2 + 0.56045)**3 + 0.18/(r**2 + 0.56045)**2) + 100*(-6.0*r**2*np.sqrt(r**2 + 0.47045)/(r**2 + 0.56045)**2.5 + 2*r**2/(np.sqrt(r**2 + 0.47045)*(r**2 + 0.56045)**1.5) + 0.36*r*(r**2 + 0.47045)/(r**2 + 0.56045)**3 - 0.18*r/(r**2 + 0.56045)**2 + 2*np.sqrt(r**2 + 0.47045)/(r**2 + 0.56045)**1.5)/r**3 - (0.12 - 0.27/(r*np.sqrt(1 + 0.09/r**2)) + 0.0081/(r**3*(1 + 0.09/r**2)**(3/2)))/(r**3*(1 + 0.09/r**2)**3) + 150*(-2*r*np.sqrt(r**2 + 0.47045)/(r**2 + 0.56045)**1.5 + (0.09*r**2 + 0.0423405)/(r**2 + 0.56045)**2 + 1)/r**4 - (1.62*np.sqrt(1 + 0.09/r**2) - 0.0972/r)/(r**4*(1 + 0.09/r**2)**4) + (0.0648 - 0.0972/(r*np.sqrt(1 + 0.09/r**2)))/(r**5*(1 + 0.09/r**2)**4) + (0.3888*np.sqrt(1 + 0.09/r**2) - 0.023328/r)/(r**6*(1 + 0.09/r**2)**5)

r = np.linspace(3, 10, 100)
plt.ylim(-0.05,0.05)
plt.plot(r, f(r))
plt.axhline(color = 'k')
root, info = brentq(f, 3, 4, full_output=True)
plt.axvline(x=root, color = 'r', **{'linestyle': 'dashed'})
print(root)
# Out:
# 3.915649651250019
